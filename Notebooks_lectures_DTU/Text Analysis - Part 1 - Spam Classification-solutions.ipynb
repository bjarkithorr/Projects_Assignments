# %% [markdown]
# *Francisco Pereira [camara@dtu.dk], DTU Management*
#
# *Stanislav Borysov [stabo@dtu.dk], DTU Management*
#
# # Advanced Business Analytics

# %% [markdown]
# ## Lecture 2 - Text Analytics - Part 1: Spam Classification

# %% [markdown]
# Given that language remains a primary means of communication between humans, a lot of extremely useful data come in a natural language form. However, given its complexity and ambiguity, representing these data in a suitable form for automatic processing is a very difficult research challenge. In this exercise, we will get familiar with some basic text analysis techniques. As an exercise, we will try to classify SMS messages for spam detection. The data was downloaded from http://www.dt.fee.unicamp.br/~tiago/smsspamcollection/

# %% [markdown]
# ### 1. Descriptive data analysis

# %% [markdown]
# As usual in data science, we will start with descriptive data analysis to understand the data structure and get useful insights. Load the data from `smsspamcollection/SMSSpamCollection.txt` and print the number of spam and non-spam ("ham") messages.

# %%
import pandas as pd
import numpy as np

data_df = pd.read_csv("smsspamcollection/SMSSpamCollection.txt", 
                      sep="\t", 
                      header=None,
                      names=['type', 'message'])

# %%
data_df.head()
# Out:
#    type                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
print("Total number of messages:", len(data_df))
print("Number of spam messages:", len(data_df[data_df['type'] == 'spam']))
print("Number of ham messages:", len(data_df[data_df['type'] == 'ham']))
# Out:
# Total number of messages: 5572
# Number of spam messages: 747
# Number of ham messages: 4825

# %% [markdown]
# Note that the data is imbalanced, which is very common in such types of problems. Now, plot histogram of message lengths and print average message length for each message type.

# %%
data_df['message_len'] = data_df['message'].apply(len)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

data_df.hist(column='message_len', by='type', bins=50, figsize=(11,5));

# %%
print("Average length of spam:", data_df[data_df['type'] == 'spam']['message_len'].mean())
print("Average length of ham:", data_df[data_df['type'] == 'ham']['message_len'].mean())
# Out:
# Average length of spam: 138.6706827309237
# Average length of ham: 71.48248704663213

# %% [markdown]
# The very first insight: The spam messages tend to be longer! It might be a useful feature in our classification problem. Let's visualize the most popular words for each category using word clouds. You can use either the `wordcloud` Python package or some external websites such as https://www.wordclouds.com/

# %%
import wordcloud

def show_wordcloud(data_spam_or_ham, title):
    text = ' '.join(data_spam_or_ham['message'].astype(str).tolist())
    stopwords = set(wordcloud.STOPWORDS)
    
    fig_wordcloud = wordcloud.WordCloud(stopwords=stopwords,
        max_font_size=100, max_words=100, background_color="white").generate(text)
    
    plt.figure(figsize=(10,7), frameon=True)
    plt.imshow(fig_wordcloud, interpolation="bilinear")  
    plt.axis('off')
    plt.title(title, fontsize=20)
    plt.show()

# %%
# word cloud of ham messages
show_wordcloud(data_df[data_df.type=='ham'], "Ham messages")

# %%
# word cloud of spam messages
show_wordcloud(data_df[data_df.type=='spam'], "Spam messages")

# %% [markdown]
# These word clouds suggest that using words as features for our classification problem can be a not bad idea.

# %% [markdown]
# ### 2. Text preprocessing

# %% [markdown]
# First, we need to do some text preprocessing, commonly referred to as "normalization". Text preprocessing is usually the most crucial and time-consuming part of the NLP pipeline. In this exercise, it will include the following simple steps:
#
# 1. Removing punctuation
# 2. Converting text to lowercase *(Side note: This step is questionable since spammers tend to use more uppercase letters)*
# 3. Removing stopwords (either using a predefined list of the English stopwords or using the most frequent words in the text directly)
# 4. (Optional) Stemming or lemmatizing
#
# This list is, of course, is incomplete and other steps can also include removing rare words, removing numbers, synonymizing, handling negation, etc.
#
# In Python, there are many NLP packages available, such as `NLTK` (the most popular one), `Gensim`, or `spaCy`, however, we will mostly use the basic functionality provided by `sklearn`. For stemming or lemmatizing, one can use the `NLTK` library.
#
# *Side note: In principle, all preprocessing should be done on the train and test sets separately. However, we will skip this for simplicity.*

# %%
from stopwords import get_stopwords
import string
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

stop_words=get_stopwords('en')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-dbf59ef89618> in <module>
# ----> 1 from stopwords import get_stopwords
#       2 import string
#       3 from nltk.stem import WordNetLemmatizer
#       4 lemmatizer = WordNetLemmatizer()
#       5
#
# ModuleNotFoundError: No module named 'stopwords'

# %%
def text_processing(text):
    # remove punctuation 
    text = "".join([c for c in text 
                    if c not in string.punctuation])
    # lowercase
    text = "".join([c.lower() for c in text])
    # remove stopwords
    text = " ".join([w for w in text.split() 
                     if w not in stop_words])
    # stemming / lematizing (optional)
    text = " ".join([lemmatizer.lemmatize(w) for w in text.split()])
    return text

# %%
data_df['message_clean'] = data_df['message'].apply(text_processing)

# %% [markdown]
# Print a few messages to check how the preprocessed messages differ from the raw ones.

# %%
data_df[['message', 'message_clean']].head(5).values
# Out:
# array([['Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...',
#         'go jurong point crazy available bugis n great world la e buffet cine got amore wat'],
#        ['Ok lar... Joking wif u oni...', 'ok lar joking wif u oni'],
#        ["Free entry in 2 a wkly comp to win FA Cup final tkts 21st May 2005. Text FA to 87121 to receive entry question(std txt rate)T&C's apply 08452810075over18's",
#         'free entry 2 wkly comp win fa cup final tkts 21st may 2005 text fa 87121 receive entry questionstd txt ratetcs apply 08452810075over18s'],
#        ['U dun say so early hor... U c already then say...',
#         'u dun say early hor u c already say'],
#        ["Nah I don't think he goes to usf, he lives around here though",
#         'nah dont think go usf life around though']], dtype=object)

# %% [markdown]
# Let's now represent the text in a format which can be used in machine learning. Since we will use a vector format for the messages ("documents"), this process is called "vectorization". We will use a simple "bag-of-words" (BoW) representation on a single word level (1-grams). First, let's do simple word counts, where `sklearn.feature_extraction.text.CountVectorizer` can be particularly useful. Such vectorizers convert the whole corpora to a document-term matrix of size $N\times M$, where $N$ is a number of documents (messages), $M$ is a vocabulary size (number of different words in the corpora), and each element $d_{ij}$ corresponds to the number (or frequency, or tf-idf, etc) of the word $j$ in the document $i$. As each document is usually far from containing all the words from vocabulary, the matrix is usually very sparse (has a lot of 0's).

# %%
from sklearn.feature_extraction.text import CountVectorizer

count_vect = CountVectorizer()
bow_counts = count_vect.fit_transform(data_df['message_clean'].values)
print(bow_counts[0])
# Out:
#   (0, 3615)	1
#   (0, 4467)	1
#   (0, 6091)	1
#   (0, 2402)	1
#   (0, 1390)	1
#   (0, 1830)	1
#   (0, 3706)	1
#   (0, 8662)	1
#   (0, 4620)	1
#   (0, 1828)	1
#   (0, 2140)	1
#   (0, 3668)	1
#   (0, 1166)	1
#   (0, 8440)	1

# %% [markdown]
# Print the vocabulary size (you can get the whole vocabulary with count_vect.vocabulary_). It should be close to 9000 (this is a huge number of features!).

# %%
print(len(count_vect.vocabulary_))
# Out:
# 8909

# %% [markdown]
# It is often useful to also create the inverse mapping of the vocabulary_. The inverse mapping (let's call it **index_to_word**), is a dictionary where the keys are the indexes, and the values are the words)

# %%
index_to_word= {v: k for k, v in count_vect.vocabulary_.items()}

# %% [markdown]
# Now let's weight the term frequencies by inverse document frequency (tf-idf representation).
#
# *Hint: `sklearn` has this functionality as well, check `sklearn.feature_extraction.text.TfidfTransformer`*

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tf_transformer = TfidfTransformer()
bow_tfidf = tf_transformer.fit_transform(bow_counts)
print(bow_tfidf[0])
# Out:
#   (0, 8662)	0.23716884709034444
#   (0, 8440)	0.19898753144041254
#   (0, 6091)	0.23830139318791047
#   (0, 4620)	0.2948326691905571
#   (0, 4467)	0.3489953348778522
#   (0, 3706)	0.1942459500636148
#   (0, 3668)	0.16378058070686363
#   (0, 3615)	0.15482420944980274
#   (0, 2402)	0.27027286311810905
#   (0, 2140)	0.2948326691905571
#   (0, 1830)	0.2948326691905571
#   (0, 1828)	0.3331537706947702
#   (0, 1390)	0.265382726031558
#   (0, 1166)	0.3489953348778522

# %%
print(bow_tfidf[0])
# Out:
#   (0, 8662)	0.23716884709034444
#   (0, 8440)	0.19898753144041254
#   (0, 6091)	0.23830139318791047
#   (0, 4620)	0.2948326691905571
#   (0, 4467)	0.3489953348778522
#   (0, 3706)	0.1942459500636148
#   (0, 3668)	0.16378058070686363
#   (0, 3615)	0.15482420944980274
#   (0, 2402)	0.27027286311810905
#   (0, 2140)	0.2948326691905571
#   (0, 1830)	0.2948326691905571
#   (0, 1828)	0.3331537706947702
#   (0, 1390)	0.265382726031558
#   (0, 1166)	0.3489953348778522

# %% [markdown]
# Just to get an idea of the TFIDF results, you could print, for each message, which word has the highest TFIDF value.
#
# You want the output to look something like:
#
# ```
# amore --> jurong point crazy available bugis n great world la e buffet cine got amore wat
# oni --> ok lar joking wif u oni
# fa --> free entry 2 wkly comp win fa cup final tkts 21st 2005 text fa 87121 receive entry questionstd txt ratetcs apply 08452810075over18s
# say --> u dun say early hor u c say
# nah --> nah dont think go usf life```

# %%
for b_tfidf, text in zip(bow_tfidf, data_df['message_clean']):
    print(index_to_word[np.argsort(b_tfidf.toarray())[0][-1]], "-->", text) #ordered by the highest TFIDF
# Out:
# jurong --> go jurong point crazy available bugis n great world la e buffet cine got amore wat
# oni --> ok lar joking wif u oni
# fa --> free entry 2 wkly comp win fa cup final tkts 21st may 2005 text fa 87121 receive entry questionstd txt ratetcs apply 08452810075over18s
# say --> u dun say early hor u c already say
# nah --> nah dont think go usf life around though
# chgs --> freemsg hey darling 3 week now word back id like fun still tb ok xxx std chgs send £150 rcv
# patent --> even brother like speak treat like aid patent
# melle --> per request melle melle oru minnaminunginte nurungu vettam set callertune caller press 9 copy friend callertune
# claim --> winner valued network customer selected receivea £900 prize reward claim call 09061701461 claim code kl341 valid 12 hour
# mobile --> mobile 11 month u r entitled update latest colour mobile camera free call mobile update co free 08002986030
# cried --> im gonna home soon dont want talk stuff anymore tonight k ive cried enough today
# tsandcs --> six chance win cash 100 20000 pound txt csh11 send 87575 cost 150pday 6days 16 tsandcs apply reply hl 4 info
# 4403ldnw1a7rw18 --> urgent won 1 week free membership £100000 prize jackpot txt word claim 81010 tc wwwdbuknet lccltd pobox 4403ldnw1a7rw18
# promise --> ive searching right word thank breather promise wont take help granted will fulfil promise wonderful blessing time
# sunday --> date sunday will
# click --> xxxmobilemovieclub use credit click wap link next txt message click httpwap xxxmobilemovieclubcomnqjkgighjjgcbl
# kim --> oh kim watching
# spell --> eh u remember 2 spell name yes v naughty make v wet
# that --> fine thats way u feel thats way gota b
# 87077 --> england v macedonia dont miss goalsteam news txt ur national team 87077 eg england 87077 trywales scotland 4txtú120 poboxox36504w45wq 16
# spell --> seriously spell name
# ha --> i‘m going try 2 month ha ha joking
# stock --> ü pay first lar da stock comin
# lunch --> aft finish lunch go str lor ard 3 smth lor u finish ur lunch already
# ffffffffff --> ffffffffff alright way can meet sooner
# forced --> just forced eat slice im really hungry tho suck mark getting worried know im sick turn pizza lol
# convincing --> lol always convincing
# frying --> catch bus frying egg make tea eating mom left dinner feel love
# packing --> im back amp packing car now ill let know there room
# ahhh --> ahhh work vaguely remember feel like lol
# thats --> wait thats still clear sure sarcastic thats x doesnt want live u
# apologetic --> yeah got 2 v apologetic n fallen actin like spoilt child got caught till 2 wont go badly cheer
# anything --> k tell anything
# housework --> fear fainting housework just quick cuppa
# charged --> thanks subscription ringtone uk mobile will charged £5month please confirm replying yes reply will charged
# 8am --> yup ok go home look timing msg ü xuhui going learn 2nd may lesson 8am
# roommate --> oops ill let know roommate done
# letter --> see letter b car
# decide --> anything lor u decide
# anything --> hello hows saturday go just texting see youd decided anything tomo im trying invite anything
# watt --> pls go ahead watt just wanted sure great weekend abiola
# steed --> forget tell want need crave love sweet arabian steed mmmmmm yummy
# rodger --> 07732584351 rodger burn msg tried call re reply sm free nokia mobile free camcorder please call now 08000930705 delivery tomorrow
# seeing --> seeing
# endowed --> great hope like man well endowed ltgt inch
# callsmessagesmissed --> callsmessagesmissed call
# immunisation --> didnt get hep b immunisation nigeria
# fair --> fair enough anything going
# hopefully --> yeah hopefully tyler cant maybe ask around bit
# sucker --> u dont know stubborn didnt even want go hospital kept telling mark im weak sucker hospital weak sucker
# thinked --> thinked first time saw class
# gram --> gram usually run like ltgt half eighth smarter though get almost whole second gram ltgt
# crashing --> k fyi x ride early tomorrow morning he crashing place tonight
# sorry --> wow never realized embarassed accomodations thought liked since best always seemed happy cave im sorry didnt dont give im sorry offered im sorry room embarassing
# sptv --> sm ac sptv new jersey devil detroit red wing play ice hockey correct incorrect end reply end sptv
# sherawat --> know mallika sherawat yesterday find now lturlgt
# 09061209465 --> congrats 1 year special cinema pas 2 call 09061209465 now c suprman v matrix3 starwars3 etc 4 free bx420ip45we 150pm dont miss
# meeting --> sorry ill call later meeting
# reached --> tell reached
# sehwag --> yesgauti sehwag odi series
# killing --> gonna pick 1 burger way home cant even move pain killing
# ha --> ha ha ha good joke girl situation seeker
# iq --> part checking iq
# roommate --> sorry roommate took forever ok come now
# cut --> ok lar double check wif da hair dresser already said wun cut v short said will cut look nice
# 09066364589 --> valued customer pleased advise following recent review mob awarded £1500 bonus prize call 09066364589
# song --> today song dedicated day song will u dedicate send ur valuable frnds first rply
# 3aj --> urgent ur awarded complimentary trip eurodisinc trav acoentry41 £1000 claim txt dis 87121 186£150morefrmmob shracomorsglsuplt10 ls1 3aj
# ken --> hear new divorce barbie come ken stuff
# plane --> plane give month end
# wah --> wah lucky man can save money hee
# finished --> finished class
# xx --> hi babe im home now wanna something xx
# performed --> kkwhere youhow performed
# can --> u can call now
# machan --> waiting machan call free
# respect --> thats cool gentleman will treat dignity respect
# shy --> like people much shy pa
# operate --> operate ltgt
# earn --> still looking job much ta earn
# later --> sorry ill call later
# ah --> k call just now ah
# hi --> ok way home hi hi
# man --> will place man
# yup --> yup next stop
# urgnt --> call later dont network urgnt sm
# multis --> real u getting yo need 2 ticket one jacket im done already used multis
# back --> yes started send request make pain came back im back bed double coin factory gotta cash nitros
# tonight --> im really still tonight babe
# kanoil --> ela kanoil download come wen ur free
# you --> yeah don‘t stand close tho you‘ll catch something
# sorry --> sorry pain ok meet another night spent late afternoon casualty mean havent done y stuff42moro includes time sheet sorry
# smile --> smile pleasure smile pain smile trouble pours like rain smile sum1 hurt u smile becoz someone still love see u smiling
# 169 --> please call customer service representative 0800 169 6031 10am9pm won guaranteed £1000 cash £5000 prize
# already --> havent planning buy later check already lido got 530 show e afternoon u finish work already
# 450ppw --> free ringtone waiting collected simply text password mix 85069 verify get usher britney fml po box 5249 mk17 92h 450ppw 16
# telugu --> watching telugu moviewat abt u
# loan --> see finish load loan pay
# beforehand --> hi wk ok hols now yes bit run forgot hairdresser appointment four need get home n shower beforehand cause prob u
# animation --> see cup coffee animation
# anymore --> please dont text anymore nothing else say
# am --> okay name ur price long legal wen can pick y u ave x am xx
# 4the --> im still looking car buy gone 4the driving test yet
# melle --> per request melle melle oru minnaminunginte nurungu vettam set callertune caller press 9 copy friend callertune
# boston --> wow youre right didnt mean guess gave boston men changed search location nyc something changed cuz signin page still say boston
# umma --> umma life vava umma love lot dear
# birthday --> thanks lot wish birthday thanks making birthday truly memorable
# hit --> aight ill hit get cash
# minecraft --> ip address test considering computer isnt minecraft server
# lying --> know grumpy old people mom like better lying always one play joke
# busy --> dont worry guess he busy
# plural --> plural noun research
# dinnermsg --> going dinnermsg
# co --> im ok wif co like 2 try new thing scared u dun like mah co u said loud
# 09064012160 --> gent trying contact last weekend draw show won £1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs 150ppm
# formal --> wa ur openin sentence formal anyway im fine juz tt im eatin much n puttin weighthaha anythin special happened
# lunch --> entered cabin pa said happy bday bos felt special askd 4 lunch lunch invited apartment went
# 0871277810910pmin --> winner u specially selected 2 receive £1000 4 holiday flight inc speak live operator 2 claim 0871277810910pmin 18
# ratio --> goodo yes must speak friday eggpotato ratio tortilla needed
# hmmmy --> hmmmy uncle just informed he paying school directly pls buy food
# 07742676969 --> private 2004 account statement 07742676969 show 786 unredeemed bonus point claim call 08719180248 identifier code 45239 expires
# 5903 --> urgent mobile awarded £2000 bonus caller prize 5903 final try contact u call landline 09064019788 box42wr29c 150ppm
# applespairsall --> new address applespairsall malarky
# 7548 --> today voda number ending 7548 selected receive 350 award match please call 08712300220 quoting claim code 4041 standard rate app
# sao --> going sao mu today will done 12
# predict --> ü predict wat time üll finish buying
# stuff --> good stuff will
# sent --> just knowyetunde hasnt sent money yet just sent text bother sending dont involve anything shouldnt imposed anything first place apologise
# room --> room
# lucyxx --> hey girl r u hope u r well del r bak long time c give call sum time lucyxx
# kkhow --> kkhow much cost
# home --> im home
# accomodate --> dear will call tmorrowpls accomodate
# answer --> first answer question
# algarve --> sunshine quiz wkly q win top sony dvd player u know country algarve txt ansr 82277 £150 sptyrone
# dogging --> want 2 get laid tonight want real dogging location sent direct 2 ur mob join uk largest dogging network bt txting gravel 69888 nt ec2a 31pmsg150p
# yijuehotmailcom --> haf msn yijuehotmailcom
# meet --> call meet
# befor --> will check room befor activity
# svc --> youll rcv msg chat svc free hardcore service text go 69988 u get nothing u must age verify yr network try
# pouch --> got c lazy type forgot ü lect saw pouch like v nice
# youre --> k text youre way
# mail --> sir waiting mail
# little --> swt thought nver get tired little thing 4 lovable person cozsomtimes little thing occupy d biggest part heart gud ni8
# open --> know can pls open back
# dot --> yes see ya dot
# staff --> whats staff name taking class u
# 08700621170150p --> freemsg havent replied text im randy sexy female live local luv hear u netcollex ltd 08700621170150p per msg reply stop end
# ummmawill --> ummmawill call check inour life will begin qatar pls pray hard
# deleted --> ki deleted contact
# sindu --> sindu got job birla soft
# nevering --> wine flowing im nevering
# plaza --> yup thk cine better co need 2 go 2 plaza mah
# typical --> ok ur typical reply
# melle --> per request melle melle oru minnaminunginte nurungu vettam set callertune caller press 9 copy friend callertune
# exist --> everywhere dirt floor window even shirt sometimes open mouth come flowing dream world without half chore time joy lot tv show ill see guess like thing just must exist like rain hail mist time done become one
# aaooooright --> aaooooright work
# leaving --> im leaving house now
# meare --> hello love get interview today happy good boy think meare missing
# delivery --> customer service annoncement new year delivery waiting please call 07046744435 now arrange delivery
# 0871277810810 --> winner u specially selected 2 receive £1000 cash 4 holiday flight inc speak live operator 2 claim 0871277810810
# envy --> keep safe need miss already envy everyone see real life
# new --> new car house parentsi new job hand
# excited --> im love im excited day spend make happy
# stop --> pls stop bootydelious 32f inviting friend reply yes434 no434 see wwwsmsacubootydelious stop send stop frnd 62468
# ur --> bangbabes ur order way u receive service msg 2 download ur content u goto wap bangb tv ur mobile internetservice menu
# culture --> place ur point e culture module already
# s89 --> urgent trying contact last weekend draw show won £900 prize guaranteed call 09061701939 claim code s89 valid 12hrs
# missunderstding --> hi frnd best way avoid missunderstding wit beloved one
# bridge --> great escape fancy bridge need lager see tomo
# utter --> yes completely formclark also utter waste
# bank --> sir need axis bank account bank address
# discus --> hmmm thk sure got time hop ard ya can go 4 free abt muz call u discus liao
# coming --> time coming later
# surname --> bloody hell cant believe forgot surname mr ill give u clue spanish begin m
# goodfine --> well im gonna finish bath now goodfine night
# youve --> let know youve got money carlos can make call
# mall --> u still going mall
# ltgt --> turn friend staying whole show wont back til ltgt feel free go ahead smoke ltgt worth
# log --> text doesnt reply let know can log
# maneesha --> hi just spoke maneesha v wed like know satisfied experience reply toll free yes
# approach --> lifted hope offer money need especially end month approach hurt studying anyways gr8 weekend
# trust --> lol u can trust
# gentleman --> ok gentleman will treat dignity respect
# close --> will guy close
# greatbye --> going nothing greatbye
# finding --> hello handsome finding job lazy working towards getting back net mummy wheres boytoy now miss
# awesome --> haha awesome minute
# 0808 --> please call customer service representative freephone 0808 145 4742 9am11pm won guaranteed £1000 cash £5000 prize
# radio --> got xmas radio time will get now
# net --> jus reached home go bathe first si using net tell u finish k
# wwwareyouuniquecouk --> unique enough find 30th august wwwareyouuniquecouk
# great --> im sorry ive joined league people dont keep touch mean great deal friend time even great personal cost great week
# completed --> hi finally completed course
# or --> will stop however suggest stay someone will able give or every stool
# wishin --> hope youve settled new school year just wishin gr8 day
# mrng --> gud mrng dear hav nice day
# story --> u got person story
# 1pm --> hamster dead hey tmr meet 1pm orchard mrt
# babyjontet --> hi kate evening hope can see tomorrow bit bloody babyjontet txt back u can xxx
# enc --> found enc ltgt
# buck --> sent ltgt buck
# kate --> hello darlin ive finished college now txt u finish u can love kate xxx
# ltdecimalgt --> account refilled successfully inr ltdecimalgt keralacircle prepaid account balance r ltdecimalgt transaction id kr ltgt
# ga --> goodmorning sleeping ga
# alter --> u call alter 11 ok
# ericsson --> ü say like dat dun buy ericsson oso oredi lar
# lunch --> entered cabin pa said happy bday bos felt special askd 4 lunch lunch invited apartment went
# dogg --> aight yo dat straight dogg
# refund --> please give u connection today ltdecimalgt refund bill
# shoot --> shoot big load get ready
# bruv --> whats bruv hope great break rewarding semester
# chat --> home can always chat
# kkgoodstudy --> kkgoodstudy well
# noe --> yup ü noe leh
# sound --> sound great home now
# prediction --> finally match heading towards draw prediction
# past --> tired havent slept well past night
# ahsen --> easy ahsen got selected mean good
# march --> take exam march 3
# sure --> yeah think can use gt atm now register sure there anyway can help let know sure ready
# prob --> ok prob take ur time
# diskyou --> o called ubandu will run without installing hard diskyou can use o copy important file system give repair shop
# later --> sorry ill call later
# leh --> u say leh course nothing happen lar say v romantic jus bit lor thk e nite scenery nice leh
# todayfrom --> 500 new mobile 2004 must go txt nokia 89545 collect todayfrom £1 www4tcbiz 2optout 08718726270150gbpmtmsg18
# appreciate --> really appreciate call just need someone talk
# horo --> will u meet ur dream partner soon ur career 2 flyng start 2 find free txt horo followed ur star sign e g horo aries
# elama --> hey company elama po mudyadhu
# conduct --> life strict teacher bcoz teacher teach lesson amp conduct exam life first conduct exam amp teach lesson happy morning
# morning --> dear good morning now
# road --> get gandhipuram walk cross cut road right side ltgt street road turn first right
# rubber --> dear going rubber place
# died --> sorry battery died yeah im
# yeshere --> yeshere tv always available work place
# recdthirtyeight --> text meet someone sexy today u can find date even flirt u join 4 just 10p reply name age eg sam 25 18 msg recdthirtyeight penny
# upstairs --> printed oh ltgt come upstairs
# closer --> ill little closer like bus stop street
# youwhen --> youwhen wil reach
# loses --> new theory argument win d situation loses person dont argue ur friend just kick amp say im always correct
# 09058094597 --> u 447801259231 secret admirer looking 2 make contact ufind rreveal think ur specialcall 09058094597
# hearing --> tomarrow final hearing laptop case cant
# pleassssssseeeeee --> pleassssssseeeeee tel v avent done sportsx
# shining --> okay just shining meant signing sound better
# watch --> although told u dat im baig face watch now really like e watch u gave co fr u thanx 4 everything dat uve done today im touched
# commercial --> u dont remember old commercial
# slipper --> late said website didnt dont slipper
# asked --> asked call now ok
# inning --> kallis wont bat 2nd inning
# dearly --> didnt work oh ok goodnight ill fix ready time wake dearly missed good night sleep
# 125gift --> congratulation ur awarded 500 cd voucher 125gift guaranteed free entry 2 100 wkly draw txt music 87066 tncs wwwldewcom1win150ppmx3age16
# deepak --> ranjith cal drpd deeraj deepak 5min hold
# angry --> wen ur lovable bcums angry wid u dnt take seriously coz angry d childish n true way showing deep affection care n luv kettoda manda nice day da
# doinghow --> doinghow
# take --> ups 3days also shipping company take 2wks way usps take week get lag may bribe nipost get stuff
# lemme --> im back lemme know youre ready
# headin --> dont necessarily expect done get back though im just now headin
# suzy --> mmm yummy babe nice jolt suzy
# lover --> lover need
# reply --> tried contact re reply offer video handset 750 anytime network min unlimited text camcorder reply call 08000930705 now
# parked --> i‘m parked next mini coming today think
# yup --> yup
# disturb --> anyway im going shopping now co si done yet dun disturb u liao
# 0125698789 --> luton 0125698789 ring ur around h
# 69698 --> hey really horny want chat see naked text hot 69698 text charged 150pm unsubscribe text stop 69698
# dint --> dint come u
# sometme --> wana plan trip sometme
# hold --> sure yet still trying get hold
# stop --> ur ringtone service changed 25 free credit go club4mobilescom choose content now stop txt club stop 87070 150pwk club4 po box1146 mk45 2wt
# evo --> evo just download flash jealous
# ringtone --> ringtone club get uk single chart mobile week choose top quality ringtone message free charge
# narcotic --> come mu sorting narcotic situation
# blue --> night ended another day morning come special way may smile like sunny ray leaf worry blue blue bay
# hmv --> hmv bonus special 500 pound genuine hmv voucher won just answer 4 easy question play now send hmv 86688 infowww100percentrealcom
# usf --> usf guess might well take 1 car
# objection --> objection bf coming
# thanx --> thanx
# theater --> tell rob mack gf theater
# awesome --> awesome ill see bit
# type --> just sent type food like
# celebration --> done handed celebration full swing yet
# tool --> got called tool
# special --> wen u miss someone person definitely special u person special miss just keepintouch gdeve
# far --> ok asked money far
# okie --> okie
# ahold --> yeah think usual guy still passed last night get ahold anybody let know ill throw
# early --> k might come tonight class let early
# ok --> ok
# fone --> hi baby im cruisin girl friend r u 2 give call hour home thats alright fone fone now love jenny xxx
# life --> life mean lot love life love people life world call friend call world ge
# edukkukayee --> dearshall mail tonitebusy streetshall update tonitethings looking okvarunnathu edukkukayee raksha ollubut good one real sense
# gautham --> hey told name gautham ah
# cam --> haf u found feel stupid da v cam working
# oops --> oops 4 got bit
# buzy --> much buzy
# resend --> accidentally deleted message resend please
# 28thfebtcs --> tmobile customer may now claim free camera phone upgrade pay go sim card loyalty call 0845 021 3680offer end 28thfebtcs apply
# gurl --> unless situation go gurl appropriate
# grave --> hurt tease make cry end life die plz keep one rose grave say stupid miss u nice day bslvyl
# pick --> cant pick phone right now pls send message
# tomocant --> need coffee run tomocant believe time week already
# diesel --> awesome remember last time got somebody high first time diesel v
# night --> shit really shocking scary cant imagine second def night u think somewhere crash night save taxi
# fridge --> oh way food fridge want go meal tonight
# womdarfull --> womdarfull actor
# blind --> sm ac blind date 4u rodds1 21m aberdeen united kingdom check httpimg sm acwicmb3cktz8r74 blind date send hide
# remb --> yup remb think can book
# jos --> jos ask u wana meet
# thread --> lol yes friendship hanging thread cause u wont buy stuff
# 82468 --> themob check newest selection content game tone gossip babe sport keep mobile fit funky text wap 82468
# bookshelf --> garage key arent bookshelf
# accept --> today accept dayu accept brother sister lover dear1 best1 clos1 lvblefrnd jstfrnd cutefrnd lifpartnr belovd swtheart bstfrnd rply mean enemy
# gbp150week --> think ur smart win £200 week weekly quiz text play 85222 nowtcs winnersclub po box 84 m26 3uz 16 gbp150week
# definitely --> say hell give call friend got money he definitely buying end week
# hope --> hi way u 2day normal waythis real ur uniquei hope know u 4 rest mylife hope u find wot lost
# day --> made day great day
# kkadvance --> kkadvance happy pongal
# yoga --> hmmm guess can go 4 kb n power yoga haha dunno can tahan power yoga anot thk got lo oso forgot liao
# afraid --> really dude friend im afraid
# mobile --> december mobile 11mths entitled update latest colour camera mobile free call mobile update co free 08002986906
# cake --> coffee cake guess
# merry --> merry christmas babe love ya kiss
# men --> hey dont just go watch x men lunch haha
# co --> cud u tell ppl im gona b bit l8 co 2 bus hav gon past co full im still waitin 4 1 pete x
# guild --> great well guild meet bristol road somewhere will get touch weekend plan take flight good week
# problem --> problem
# callsmessagesmissed --> callsmessagesmissed call
# dahow --> hi dahow today class
# track --> id say thats good sign well know track record reading woman
# parked --> cool text youre parked
# joke --> im reading text just sent meant joke read light
# kgood --> kkapo kgood movie
# immediately --> maybe get book tomo return immediately something
# 85 --> call germany 1 penny per minute call fixed line via access number 0844 861 85 85 prepayment direct access
# evaporated --> chance might evaporated soon violated privacy stealing phone number employer paperwork cool please contact will report supervisor
# custcare08718720201 --> valentine day special win £1000 quiz take partner trip lifetime send go 83600 now 150pmsg rcvd custcare08718720201
# tadaaaaa --> tadaaaaa home babe still
# dined --> cool come havent wined dined
# sleepingand --> just sleepingand surfing
# later --> sorry ill call later
# hand --> u calling right call hand phone
# thanx --> ok thats great thanx lot
# caroline --> take post come must 1000 text now happy reading one wiv hello caroline end favourite bless
# hiding --> u hiding stranger
# interested --> interested like
# cleared --> sister cleared two round birla soft yesterday
# gudnitetcpractice --> gudnitetcpractice going
# num --> dis yijue jus saw ur mail case huiming havent sent u num dis num
# prestige --> one small prestige problem now
# shag --> fancy shag dointerested sextextukcom txt xxuk suzy 69876 txts cost 150 per msg tncs website x
# jeremiah --> just checking really miss seeing jeremiah great month
# iphone --> nah cant help ive never iphone
# apeshit --> youre car hour half im going apeshit
# plz --> today sorry day ever angry ever misbehaved hurt plz plz just slap urself bcoz ur fault im basically good
# figure --> yo guy ever figure much need alcohol jay trying figure much can safely spend weed
# minute --> ltgt ish minute 5 minute ago wtf
# callingforgot --> thank callingforgot say happy onam sirjii fine remembered met insurance personmeet qatar insha allahrakhesh ex tata aig joined tisscotayseer
# 125gift --> congratulation ur awarded 500 cd voucher 125gift guaranteed free entry 2 100 wkly draw txt music 87066 tncs wwwldewcom1win150ppmx3age16
# 08708800282 --> ur cashbalance currently 500 pound maximize ur cashin now send cash 86688 150pmsg cc 08708800282 hgsuite3422lands roww1j6hl
# unemployed --> im actor work work evening sleep late since im unemployed moment always sleep late youre unemployed every day saturday
# andrewsboy --> hello just got st andrewsboy long way cold will keep posted
# ha --> ha ha cool cool chikku chikkudb
# prob --> oh ok prob
# audreys --> check audreys status right now
# forward --> busy trying finish new year looking forward finally meeting
# dawn --> good afternoon sunshine dawn day refreshed happy alive breathe air smile think love always
# worry --> well know z will take care worry
# call2optoutf4q --> updatenow xmas offer latest motorola sonyericsson nokia free bluetooth double min 1000 txt orange call mobileupd8 08000839402 call2optoutf4q
# stop --> discount code rp176781 stop message reply stop wwwregalportfoliocouk customer service 08717205546
# uniform --> wat uniform get
# ready --> cool text youre ready
# cuddling --> hello boytoy geeee miss already just woke wish bed cuddling love
# spoil --> will spoil bed well
# bath --> im going bath will msg next ltgt min
# pay --> cant keep talking people sure can pay agree price pls tell want really buy much willing pay
# 09057039994 --> thanks ringtone order reference t91 will charged gbp 4 per week can unsubscribe anytime calling customer service 09057039994
# happen --> can say happen
# recognise --> seen mei didt recognise face
# heron --> well there lot thing happening lindsay new year sigh bar ptbo blue heron something going
# rinu --> keep payasam rinu brings
# taught --> taught ranjith sir called sm like becaus he verifying project prabu told today pa dont mistake
# worry --> guess thats re worried must know there way body repair im quite sure shouldnt worry well take slow first test will guide ovulation just relax nothing youve said reason worry ill keep followin
# wallet --> yeah sure give couple minute track wallet
# deal --> hey leave big deal take care
# 945 --> hey will late ah meet 945
# call2optoutn9dx --> double min txts 4 6months free bluetooth orange available sony nokia motorola phone call mobileupd8 08000839402 call2optoutn9dx
# owl --> took mr owl 3 lick
# customer --> customer place will call
# mm --> mm time dont like fun
# phone --> 4mths half price orange line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 update now or2stoptxt
# buffet --> yup lunch buffet now u eat already
# fr --> huh late fr dinner
# kickboxing --> hey sat going intro pilate kickboxing
# morning --> morning can ok
# think --> yes think office lap room think thats last day didnt shut
# 730ish --> pick bout 730ish time going
# performance --> performance award calculated every two monthnot current one month period
# text --> actually sleeping still might u call back text gr8 rock si will send u text wen wake
# picture --> always putting business put picture as facebook one open people ive ever met think picture room hurt make feel violated
# sometimerakheshvisitor --> good evening sir al salam wahleykkumsharing happy newsby grace god got offer tayseertissco joinedhope fineinshah allahmeet sometimerakheshvisitor india
# administrator --> hmmmkbut want change field quickly dai wanna get system administrator network administrator
# 87131 --> free ringtone text first 87131 poly text get 87131 true tone help 0845 2814032 16 1st free tone 3x£150pw e£nd txt stop
# chechi --> dear chechi talk
# shipped --> hair cream shipped
# none --> none thats happening til get though
# burning --> yep great loxahatchee xmas tree burning ltgt start hour
# stoner --> haha get used driving usf man know lot stoner
# fav --> well slightly disastrous class pm fav darling hope day ok coffee wld good cant stay late tomorrow time place always
# fancy --> hello good week fancy drink something later
# busetop --> headin towards busetop
# missing --> messagesome text missing sendername missing number missing sentdate missing missing u lot thats y everything missing sent via fullonsmscom
# iron --> come room point can iron plan weekend
# co --> co want thing
# blah --> okies ill go yan jiu can skip ard oso go cine den go mrt one blah blah blah
# wendy --> bring home wendy d
# 09064012103 --> 100 dating service call 09064012103 box334sk38ch
# whatsup --> whatsup dont u want sleep
# goal --> alright new goal now
# wwwtxttowincouk --> free entry £250 weekly competition just text word win 80086 now 18 tc wwwtxttowincouk
# head --> alright ill head minute text meet
# love --> send logo 2 ur lover 2 name joined heart txt love name1 name2 mobno eg love adam eve 07123456789 87077 yahoo pobox36504w45wq txtno 4 ad 150p
# yesfrom --> yesfrom last week im taking live call
# pobox12n146tf150p --> someone contacted dating service entered phone fancy find call landline 09111032124 pobox12n146tf150p
# siva --> siva hostel aha
# 09058094455 --> urgent mobile number awarded £2000 prize guaranteed call 09058094455 land line claim 3030 valid 12hrs
# 6romantic --> send ur friend receive something ur voice speaking expression 1childish 2naughty 3sentiment 4rowdy 5ful attitude 6romantic 7shy 8attractive 9funny ltgt irritating ltgt lovable reply
# ok --> ok shell ok guess
# aathiwhere --> aathiwhere dear
# urination --> pain urination thing else
# esplanade --> 7 esplanade ü mind giving lift co got car today
# ltgt --> wnt buy bmw car urgentlyits vry urgentbut hv shortage ltgt lacsthere source arng dis amt ltgt lacsthats prob
# tv --> home watching tv lor
# fifteen --> usually take fifteen fucking minute respond yes question
# call --> congrats nokia 3650 video camera phone call 09066382422 call cost 150ppm ave call 3mins vary mobile 16 close 300603 post bcm4284 ldn wc1n3xx
# pongal --> booked ticket pongal
# hillsborough --> available now im like right around hillsborough amp ltgt th
# ltgt --> message sent askin ltgt dollar shoul pay ltgt ltgt
# iouri --> ask g iouri ive told story like ten time already
# applebees --> long applebees fucking take
# gdnow --> hi hope u get txtjourney hasnt gdnow 50 min late think
# arrange --> like love arrange
# sachin --> yeshe really greatbhaji told kallis best cricketer sachin worldvery tough get
# gt --> supposed wake gt
# oic --> oic saw tot din c found group liao
# later --> sorry ill call later
# hey --> hey hey werethe monkeespeople say monkeyaround howdy gorgeous howu doin foundurself jobyet sausagelove jen xxx
# gram --> sorry battery died can come im getting gram now wheres place
# blimey --> well done blimey exercise yeah kinda remember wot hmm
# concentration --> wont get concentration dear know mind everything
# made --> lol made plan new year
# 10 --> 10 min later k
# lotsly --> hank lotsly
# thanks --> thanks hope good day today
# kkwhat --> kkwhat detail want transferacc enough
# optimistic --> ok will tell stay yeah tough optimistic thing will improve month
# help --> loan purpose £500 £75000 homeowner tenant welcome previously refused can still help call free 0800 1956669 text back help
# si --> si si think ill go make oreo truffle
# don --> look amy ure beautiful intelligent woman like u lot know u dont like like dont worry
# consistently --> hope thats result consistently intelligent kind start asking practicum link keep ear open best ttyl
# ya --> 120 call cost guess isnt bad miss ya need ya want ya love ya
# feelingwavering --> going thru different feelingwavering decision coping individualtime will heal everything believe
# die --> u go phone gonna die stay
# reason --> great never better day give even reason thank god
# upgrdcentre --> upgrdcentre orange customer may now claim free camera phone upgrade loyalty call now 0207 153 9153 offer end 26th july tc apply optout available
# bye --> sorry ill call later ok bye
# railway --> ok way railway
# oral --> great princess love giving receiving oral doggy style fave position enjoy making love ltgt time per night
# slippery --> dont put stuff road keep getting slippery
# bike --> going ride bike
# rain --> yup need ill jus wait 4 e rain 2 stop
# language --> many company tell language
# okmail --> okmail dear dave final notice collect 4 tenerife holiday 5000 cash award call 09061743806 landline tc sae box326 cw25wx 150ppm
# screamed --> long since screamed princess
# account --> nothing meant money enters account bank will remove flat rate someone transfered ltgt account ltgt dollar got removed bank differ charge also differbe sure trust 9ja person sending account detail co
# dogging --> want 2 get laid tonight want real dogging location sent direct 2 ur mob join uk largest dogging network txting moan 69888nyt ec2a 31pmsg150p
# infront --> nice line said broken heart plz dont cum 1 time infront wise ll trust u good 9t
# fifteen --> ok im gonna head usf like fifteen minute
# aathilove --> love aathilove u lot
# machiany --> tension ahwhat machiany problem
# 8th --> k can pick another 8th youre done
# mcr --> whenre guy getting back g said thinking staying mcr
# sec --> almost see u sec
# asking --> yo carlos friend already asking working weekend
# tv --> watching tv lor
# taste --> thank baby cant wait taste real thing
# thuglyfe --> change fb jaykwon thuglyfe falconerf
# side --> win really 1 side long time
# message --> free message activate 500 free text message replying message word free term condition visit www07781482378com
# railway --> dear reached railway happen
# ralphs --> depends quality want type sent boye faded glory 6 want ralphs maybe 2
# fixed --> think ive fixed can send test message
# trade --> sorry man account dry want trade back half buy shit credit card
# 09061209465 --> congrats 1 year special cinema pas 2 call 09061209465 now c suprman v matrix3 starwars3 etc 4 free bx420ip45we 150pm dont miss
# sorryin --> sorryin meeting ill call later
# reunion --> class ltgt reunion
# nowcan --> free nowcan call now
# meh --> got meh
# replied --> nope think will go monday sorry replied late
# accenture --> told accenture confirm true
# jackson --> kate jackson rec center 7ish right
# reache --> dear reache room
# lose --> fighting world easy u either win lose bt fightng some1 close u dificult u lose u lose u win u still lose
# come --> can ü come
# nuerologist --> check nuerologist
# lolnice --> lolnice went fish water
# 09050002311 --> 123 congratulation week competition draw u won £1450 prize claim just call 09050002311 b4280703 tcsstop sm 08718727868 18 150ppm
# wat --> waiting e car dat bored wat co wait outside got nothing 2 home can stuff watch tv wat
# westshore --> maybe westshore hyde park village place near house
# need --> know now hows anthony bringing money ive school fee pay rent stuff like thats need help friend need
# significance --> whats significance
# kusruthi --> opinion 1 2 jada 3 kusruthi 4 lovable 5 silent 6 spl character 7 matured 8 stylish 9 simple pls reply
# ammo --> 8 latest g still can scrounge ammo want give new ak try
# sorydarealyfrm --> prabhaim sorydarealyfrm heart im sory
# forgiven --> lol ok forgiven
# nojst --> nojst change tat
# 150pmtmsgrcvd18 --> guaranteed latest nokia phone 40gb ipod mp3 player £500 prize txt word collect 83355 ibhltd ldnw15h 150pmtmsgrcvd18
# sno --> sno competition
# cha --> boltblue tone 150p reply poly mono eg poly3 1 cha cha slide 2 yeah 3 slow jamz 6 toxic 8 come stop 4 tone txt
# tgxxrz --> credit topped httpwwwbubbletextcom renewal pin tgxxrz
# way --> way transport le problematic sat night way u want ask n join bday feel free need know definite no booking fri
# abnormally --> usually person unconscious thats child adult may just behave abnormally ill call now
# ebay --> thats ebay might le elsewhere
# pickle --> shall come get pickle
# taco --> gonna go get taco
# rude --> thats rude campus
# 08718729755 --> urgent mobile awarded £2000 bonus caller prize 020903 2nd attempt contact call 08718729755 box95qu
# merry --> hi wont b ard 4 christmas enjoy n merry xmas
# offer --> today offer claim ur £150 worth discount voucher text yes 85023 now savamob member offer mobile t c 08717898035 £300 sub 16 unsub reply x
# lady --> yes pretty lady like single
# teletext --> will recieve tone within next 24hrs term condition please see channel u teletext pg 750
# doublefaggot --> jay say youre doublefaggot
# 181104 --> private 2003 account statement 07815296484 show 800 unredeemed sim point call 08718738001 identifier code 41782 expires 181104
# holidayso --> todaysundaysunday holidayso work
# gudnitetcpractice --> gudnitetcpractice going
# late --> ill late
# miss --> ive called hoping l8r malaria know miss guy miss ban big pls give love especially great day
# passionate --> good afternoon love go day hope maybe got lead job think boytoy send passionate kiss across sea
# lt --> probably gonna see later tonight lt
# button --> maybe fat finger just press button doesnt know
# many --> ummmmmaah many many happy return d day dear sweet heart happy birthday dear
# tirupur --> tirupur da started office call
# 2stop --> wwwapplausestorecom monthlysubscription50pmsg max6month tcsc web age16 2stop txt stop
# temper --> famous quote develop ability listen anything unconditionally without losing temper self confidence mean married
# pa --> going college pa else ill come self pa
# bash --> 4 oclock mine just bash flat plan
# bed --> girl stay bed girl doesnt need recovery time id rather pas fun cooped bed
# special --> special
# invitation --> know need get hotel now just got invitation apologise cali sweet come english bloke weddin
# omw --> sorry took long omw now
# wait --> wait ltgt min
# alibi --> ok give 5 minute think see btw youre alibi cutting hair whole time
# imagine --> imagine finally get sink bath put pace maybe even eat left also imagine feel cage cock surrounded bath water reminding always owns enjoy cuck
# weeddeficient --> hurry ive weeddeficient like three day
# acknowledgement --> sure get acknowledgement astoundingly tactless generally faggy demand blood oath fo
# magic --> ok every night take warm bath drink cup milk youll see work magic still need loose weight just know
# pan --> i‘ll look frying pan case it‘s cheap book perhaps that‘s silly frying pan isn‘t likely book
# mutation --> o well uv cause mutation sunscreen like essential thesedays
# lunchyou --> lunchyou onlinewhy
# told --> know friend already told
# pretty --> hi princess thank pic pretty
# reply --> aiyo u always c ex one dunno abt mei haven reply first time u reply fast y lucky workin huh got bao ur sugardad ahgee
# meim --> hi msg meim office
# brownie --> thanx 4 e brownie v nice
# geeeee --> geeeee love much can barely stand
# 09064012160 --> gent trying contact last weekend draw show won £1000 prize guaranteed call 09064012160 claim code k52 valid 12hrs 150ppm
# net --> fuck babe miss already know cant let send money towards net need want crave
# icky --> ill call u 2mrw ninish address icky american freek wont stop callin 2 bad jen k eh
# ridden --> oooh bed ridden ey thinking
# anyways --> anyways can just go gym whatever love smile hope ok good day babe miss much already
# dick --> love daddy will make scream pleasure going slap as dick
# missy --> wot u wanna missy
# clean --> yar lor wait 4 mum 2 finish sch lunch lor whole morning stay home clean room now room quite clean hee
# goggles --> know lab goggles went
# door --> can open door
# waiting --> waiting call
# daddy --> nope waiting sch 4 daddy
# call09050000327 --> won 1000 cash 2000 prize claim call09050000327
# week --> im tired arguing week week want now ill
# sch --> ü wait 4 sch finish ard 5
# claim --> mobile number won £5000 claim call u back ring claim hot line 09050005321
# bite --> arngd marriage u r walkin unfortuntly snake bite u bt love marriage dancing frnt d snake amp sayin bite bite
# izzit --> huh early ü dinner outside izzit
# change --> ok anyway need change said
# reply --> tried contact re reply offer 750 min 150 textand new video phone call 08002988890 now reply free delivery tomorrow
# kid --> exwife able kid want kid one day
# tendency --> hows scotland hope showing jjc tendency take care live dream
# headache --> tell u headache just want use 1 hour sick time
# can --> dun thk ill quit yet hmmm can go jazz yogasana oso can can go meet em lesson den
# gotany --> pete can please ring meive hardly gotany credit
# srsly --> ya srsly better yi tho
# meeting --> im meeting call later
# wwwtxt2shopcom --> ur chance win £250 wkly shopping spree txt shop 80878 tscs wwwtxt2shopcom custcare 08715705022 1x150pwk
# 08712402050 --> specially selected receive 2000 pound award call 08712402050 line close cost 10ppm 16 tc apply ag promo
# 241004 --> private 2003 account statement 07753741225 show 800 unredeemed s m point call 08715203677 identifier code 42478 expires 241004
# prix --> still grand prix
# friend --> met stranger choose friend long world stand friendship never end let friend forever gud nitz
# great --> great
# mrng --> gud mrng dear nice day
# 0825 --> important customer service announcement call freephone 0800 542 0825 now
# exhausted --> will exhausted train morning much wine pie sleep well
# ar --> im going buy mum present ar
# occur --> mind blastin tsunami will occur now rajnikant stopped swimming indian oceand
# sending --> u sending home first ok lor im ready yet
# speaking --> speaking cash yet
# noon --> happy will come noon
# la --> meet lunch la
# soon --> take care n get well soon
# zouk --> xclusiveclubsaisai 2morow 285 soiree speciale zouk nichols parisfree rose 2 lady info 0794674629107880867867
# bridgwater --> meant say cant wait see u getting bored bridgwater banter
# neva --> neva mind ok
# somethin --> fine imma get drink somethin want come find
# removed --> 22 day kick euro2004 u will kept date latest news result daily removed send get txt stop 83222
# bestrply --> valentine game send dis msg ur friend 5 answer r d someone really love u ques colour suit bestrply
# dependent --> many dependent
# soonc --> thanx4 today cer nice 2 catch ave 2 find time often oh well take care c u soonc
# himthen --> called said himthen choose future
# handsomes --> happy valentine day know early hundred handsomes beauty wish thought finish aunty uncle 1st
# telling --> like v shock leh co telling shuhui like telling leona also like dat almost know liao got ask abt ur reaction lor
# happiness --> family happiness
# come --> come n pick ü come immediately aft ur lesson
# snow --> let snow let snow kind weather brings ppl together friendship can grow
# hi --> dear got ltgt dollar hi hi
# word --> good word word may leave u dismay many time
# concerned --> make sure alex know birthday fifteen minute far youre concerned
# pub --> sorry got thing may pub later
# straight --> nah straight can just bring bud drink something thats actually little useful straight cash
# officially --> haha good hear im officially paid market 8th
# tootsie --> many lick take get center tootsie pop
# teacher --> yup thk r e teacher said will make face look longer darren ask 2 cut short
# gaytextbuddycom --> new textbuddy chat 2 horny guy ur area 4 just 25p free 2 receive search postcode gaytextbuddycom txt one name 89693
# 350 --> today vodafone number ending 4882 selected receive £350 award number match call 09064019014 receive £350 award
# hi --> please dont say like hi hi hi
# thank --> thank u
# forwarded --> oh forwarded message thought send
# seventeen --> got seventeen pound seven hundred ml – hope ok
# stop --> dear voucher holder 2 claim week offer pc go httpwwwetlpcoukexpressoffer tscs apply2 stop text txt stop 80062
# funny --> n funny
# biola --> sweetheart hope kind day one load reason smile biola
# fetching --> ü login dat time dad fetching ü home now
# shower --> will shower baby
# askd --> askd u question hour answer
# restock --> well imma definitely need restock thanksgiving ill let know im
# kiss --> said kiss kiss cant sound effect gorgeous man isnt kind person need smile brighten day
# wee --> probably gonna swing wee bit
# thursday --> ya nice ready thursday
# allo --> allo braved bus taken train triumphed mean we‘re b‘ham jolly good rest week
# amp --> watching cartoon listening music amp eve go temple amp church u
# uncomfortable --> mind ask happened dont say uncomfortable
# 08715203694 --> private 2003 account statement show 800 unredeemed s m point call 08715203694 identifier code 40533 expires 311004
# prob --> prob will send email
# rstm --> won 1000 cash 2000 prize claim call09050000327 tc rstm sw7 3 150ppm
# rough --> thats cool sometimes slow gentle sonetimes rough hard
# sorry --> im gonna say sorry normal starting panic time sorry seeing tuesday
# wesley --> wait know wesley town bet hella drug
# fine --> fine miss much
# story --> u got person story
# impatient --> tell drug dealer getting impatient
# cant --> sun cant come earth send luv ray cloud cant come river send luv rain cant come meet u can send care msg u gud evng
# man --> will place man
# wikipediacom --> doesnt make sense take unless free need know wikipediacom
# 89034 --> 88800 89034 premium phone service call 08718711108
# envelope --> sea lay rock rock envelope envelope paper paper 3 word
# repent --> mum repent
# fetch --> sorry going home first daddy come fetch ü later
# prepare --> leave de start prepare next
# kama --> yes baby can study position kama sutra
# nange --> en chikku nange bakra msg kalstiyathen teacoffee
# carlosll --> carlosll minute still need buy
# lakh --> pay ltdecimalgt lakh
# ttyl --> good evening ttyl
# receive --> u receive msg
# ho --> ho ho big belly laugh see ya tomo
# hi --> sm ac sun0819 post helloyou seem cool wanted say hi hi stop send stop 62468
# tone --> get ur 1st ringtone free now reply msg tone gr8 top 20 tone phone every week just £150 per wk 2 opt send stop 08452810071 16
# ditto --> ditto wont worry saying anything anymore like said last night whatever want ill peace
# ive --> ive got ltgt way pick
# milk --> dont knw pa just drink milk
# wetherspoons --> maybe say hi find got card great escape wetherspoons
# piggy --> piggy r u awake bet ure still sleeping im going 4 lunch now
# freaky --> cause im freaky lol
# scrappy --> missed call cause yelling scrappy miss u cant wait u come home im lonely today
# hex --> hex place talk explain
# sdryb8i --> ü log 4 wat sdryb8i
# xy --> xy going 4 e lunch
# sue --> hi im sue 20 year old work lapdancer love sex text live im bedroom now text sue 89555 textoperator g2 1da 150ppmsg 18
# lect --> wanted ask ü wait 4 finish lect co lect finish hour anyway
# finished --> finished work yet
# every --> every king cry baby every great building map imprtant u r today u wil reach tomorw gud ni8
# accordinglyor --> dearme cherthalain case u r coming cochin pls call bfore u starti shall also reach accordinglyor tell day u r comingtmorow engaged an holiday
# torch --> thanks love torch bold
# 448712404000please --> forwarded 448712404000please call 08712404000 immediately urgent message waiting
# farm --> farm open
# 1680 --> sorry trouble u can buy 4d dad 1405 1680 1843 2 big 1 small sat n sun thanx
# law --> sister law hope great month just saying hey abiola
# purchase --> will purchase d stuff today mail po box number
# poop --> ah poop look like ill prob send laptop get fixed cuz gpu problem
# entrepreneur --> good good job like entrepreneur
# alexs --> aight close still around alexs place
# corporation --> meet corporation st outside gap … can see mind working
# mum --> mum ask ü buy food home
# msg --> ku also dont msg reply msg
# willing --> much r ü willing pay
# later --> sorry ill call later
# prevent --> important prevent dehydration giving enough fluid
# weird --> thats bit weird even supposed happening good idea sure will pub
# soso --> true deari sat pray evening felt soso smsd time
# trek --> dont think can get away trek long family town sorry
# harri --> wanna gym harri
# drivin --> quite late lar ard 12 anyway wun b drivin
# nokia --> review keep fantastic nokia ngage game deck club nokia go 2 wwwcnupdatescomnewsletter unsubscribe alert reply word
# phone --> 4mths half price orange line rental latest camera phone 4 free phone 11mths call mobilesdirect free 08000938767 update now or2stoptxt tc
# ...
# correctly --> ok problem yup im going sch 4 rem correctly
# mind --> thanks ill keep mind
# bless --> aah bless hows arm
# indianpls --> dear sirsalam alaikkumpride pleasure meeting today tea shopwe pleased send contact number qatarrakhesh indianpls save numberrespectful regard
# walking --> gal n boy walking d park galcan hold ur hand boyy u think run away galno jst wana c feel walking heaven princegn
# happy --> make happy
# wishing --> wishing wonderful week
# sweet --> sweet heart
# letter --> sir waiting letter
# pisces --> dude im longer pisces im aquarius now
# 2yrs --> x course 2yrs just message messenger lik r sending
# wicket --> think steyn surely get one wicket
# resolved --> neither sterm voice im studying fine sure thing will resolved tho anyway fab hols
# chex --> garbage bag egg jam bread hannaford wheat chex
# stuffwhy --> pride im almost ltgt year old shouldnt takin money kid youre supposed deal stuff grownup stuffwhy dont tell
# costume --> sound better evening im just costume im sure time finish tomorrow will txt end
# feb --> birthday feb ltgt da
# gym --> wanna gym
# jerk --> youd like wouldnt jerk
# awake --> u awake snow
# stink --> course make stink
# wks --> u r subscribed 2 textcomp 250 wkly comp 1st wks free question follows subsequent wks charged150pmsg2 unsubscribe txt stop 2 84128custcare 08712405020
# upcharge --> go opening room til thanksgiving without upcharge
# planning --> guy planning coming
# wat --> wat ü now
# kidz --> parent kidz friend n colleague screaming surprise waiting sofa naked
# 8hr --> sir thats 8hr trip bus last week another audition next wednesday think might drive time
# put --> thought put back box
# home --> im home
# business --> one interested may business plan
# paragon --> yup paragon havent decided whether 2 cut yet hee
# princess --> good morning princess great day
# guai --> guai ü shd haf seen he naughty ü free today can go jogging
# reply --> aiyo co sm ü ü neva reply wait 4 ü reply lar tot ü havent finish ur lab wat
# simple --> living simple loving also simple laughing simple winning tooo simple simple difficult
# okay --> tell something thats okay
# ok --> ok
# bottle --> hmm shall bring bottle wine keep u amused just joking ill still bring bottle red white see tomorrow
# face --> ur face test 1 2 3 4 5 6 7 8 9 ltgt select number will tell ur face astrology waiting quick reply
# ryans --> hey iouri gave number im wylie ryans friend
# slacking --> yep get program youre slacking
# officestill --> im inside officestill filling formsdon know leave
# mentor --> think mentor 100 percent sure
# ecstacy --> call 09095350301 send girl erotic ecstacy just 60pmin stop text call 08712460324 nat rate
# camera --> camera awarded sipix digital camera call 09061221066 fromm landline delivery within 28 day
# 400 --> £400 xmas reward waiting computer randomly picked loyal mobile customer receive £400 reward just call 09066380611
# suppose --> just trying figure im suppose see couple different people week said wed get together didnt set date
# important --> important message final contact attempt important message waiting customer claim dept expires 13404 call 08717507382 now
# mom --> hi mom might back later ltgt
# datingi --> datingi two started sent text talk sport radio last week connection think coincidence
# dog --> lol oh got friend dog
# matter --> ok problem u frm wats matter
# head --> k ill head min see
# tihs --> u konw waht rael friendship im gving yuo exmpel jsut ese tihs msg evrey splleing tihs msg wrnog bt sitll yuo can raed wihtuot ayn mitsake goodnight amp nice sleepsweet dream
# pick --> cant pick phone right now pls send message
# sane --> dont want leave im barely can stay sane fighting constantly isnt helping
# 151 --> current leading bid 151 pause auction send customer care 08718726270
# psp --> free entry gr8prizes wkly comp 4 chance win latest nokia 8800 psp £250 cash every wktxt great 80878 httpwwwgr8prizescom 08715705022
# spacebucks --> somebody set website can play hold em using eve online spacebucks
# california --> sunny california weather just cool
# 02070836089 --> 1 new message call 02070836089
# squeezed --> can make squeezed ltgt buck dad
# maintaining --> good day toopray meremove teeth painful maintaining stuff
# tonight --> babe hope ok shit night sleep fell asleep 5im knackered im dreading work tonight thou upto tonight x
# problem --> friend help u problem give stupid suggestion land u another problem help u forgt previous problem
# work --> im work please call
# tight --> will gentle baby soon will taking ltgt inch deep inside tight pussy
# fight --> much fight good nite
# okthenwhats --> okok okthenwhats ur today plan
# joking --> nt joking seriously told
# ajith --> watching ajith film ah
# yoville --> ooooooh forgot tell u can get yoville phone
# asda --> done handed dont know mega shop asda count celebration thats im
# chechi --> dont know exactly ask chechi
# oni --> dunno lei shd b driving lor co go sch 1 hr oni
# officer --> want custom officer discount oh
# respectful --> thats necessarily respectful
# better --> hi hope good day better night
# bffs --> he apparently bffs carly quick now
# much --> hard true much show amp express love someonethat much will hurt leave get seperated鈥┾〨ud evening
# brolly --> babe think got ur brolly left english wil bring 2mrw 4 u luv franxx
# welli --> hi babe thanks coming even though didnt go welli just wanted bed hope see soon love kiss xxx
# cream --> gd got free ice cream oso wan
# prometazine --> pls give prometazine syrup 5mls ltgt min later feed
# since --> many day since
# dear --> dear angry busy dear
# mah --> yup msg tat yijue tot group mate co meeting today mah im askin ü leaving earlier wat mah co mayb ü haf walk v far
# pub --> pub
# everything --> first time everything
# shu --> daddy shu shu looking 4 u u wan 2 tell ure singapore wat
# ge --> ask u meeting da ge tmr nite
# victoria --> gr8 handle victoria island traffic plus whens album due
# nite --> nite nite pocay wocay luv u n e thing 4eva promise ring u 2morrowxxxx
# coast --> east coast
# ramen --> get chicken broth want ramen unless there dont know
# bright --> slave want take 2 3 picture today bright light cell phone bright light
# nope --> nope just forgot will show next week
# master --> really hows master
# fowler --> im bruce amp fowler now im mom car cant park long story
# hopefully --> dont know oh hopefully month
# elaine --> hi elaine today meeting confirmed
# sivatats --> ok ksry knw 2 sivatats y askd
# later --> sorry ill call later
# horrible --> u horrible gal u knew dat going wif yest n u still come n ask
# natuition --> otherwise part time job natuition
# flew --> oh yeah diet just flew window
# santa --> santa calling little one like call santa xmas eve call 09058094583 book time
# gist --> didnt complete gist oh
# 1526 --> er yeah will b 1526 sorry just tell pubcafe sit come wen u can
# whenever --> can make time tonight whenever can cool just text whenever youre around
# attention --> wasnt paying attention
# thanx --> thanx lot 4 ur help
# specific --> youre gonna way specific
# everybody --> jesus armand really trying tell everybody can find
# tix --> im wif now buying tix lar
# mode --> mode men left
# fne --> slow using biolas fne
# youdoing --> youdoing later sar xxx
# booked --> hey ive booked 2 lesson sun liao
# generally --> thank generally date brothas
# foregate --> way make sure u get train worc foregate street shrub hill fun night x
# get4an18th --> thought id get watch just co thats kind thing u get4an18th love much
# award --> won guaranteed 32000 award maybe even £1000 cash claim ur award call free 0800 18 legitimat efreefone number wat u think
# shopthe --> good morning repair shopthe reason im hour
# bud --> thats fine got enough bud last night least
# pendent --> back good journey let know need receipt shall tell like pendent
# away --> take away money worry
# open --> aight can pick open tonight
# stolen --> latest news police station toilet stolen cop nothing go
# sac --> sac need carry
# also --> just sing hu think also important find someone female know place well preferably citizen also smart help navigate even thing like choosing phone plan require guidance doubt ask especially girl
# wats --> hello wats talk email address
# boob --> except there chick huge boob
# wondering --> im just wondering right now
# revealing --> wishing beautiful day moment revealing even thing keep smiling enjoy
# wwwshortbreaksorguk --> sparkling shopping break 45 per person call 0121 2025050 visit wwwshortbreaksorguk
# transfr --> arun can u transfr d amt
# later --> sorry ill call later
# belong --> hear loud scream ltgt minute cause gyno will shoving thing dont belong
# mobile --> december mobile 11mths entitled update latest colour camera mobile free call mobile update co free 08002986906
# thk --> ok thk got u wan 2 come now wat
# wwwgambtv --> txt call 86888 claim reward 3 hour talk time use phone now subscribe6gbpmnth inc 3hrs 16 stoptxtstop wwwgambtv
# 2nite --> u goin 2nite
# treasure --> will treasure every moment spend together
# bring --> shall bring u bottle wine keep u amused joking i‘ll bring one anyway
# wmlid820554ad0a1705572711firsttrue --> httptms widelivecomindex wmlid820554ad0a1705572711firsttrue¡c c ringtone¡
# summer --> get garden ready summer free selection summer bulb seed worth £3350 scotsman saturday stop go2 notxtcouk
# 09050000332 --> urgent last weekend draw show won £1000 cash spanish holiday call now 09050000332 claim tc rstm sw7 3 150ppm
# lor --> ok lor
# slide --> thought slide enough
# yup --> yup
# obviously --> well obviously people cool college life went home
# reaching --> ok lor ü reaching message
# mummy --> wheres mummy boy good bad positive negative mummy made wait hmmmm
# win --> dhoni luck win big titleso will win
# command --> yes princess want please every night wish command
# holidayso --> todaysundaysunday holidayso work
# probably --> probably ltgt
# stressful --> really hope work doesnt get stressful gr8 day
# holby --> seen who back holby
# food --> shall call now dear food
# 09064017295 --> urgent trying contact last weekend draw show u won £1000 prize guaranteed call 09064017295 claim code k52 valid 12hrs 150p pm
# li --> li hai bored now da lecturer repeating last week stuff waste time
# yeovil --> picking various point going 2 yeovil will motor project 4 3 hour u take home 12 2 530 max easy
# fuck --> also fuck family going rhode island wherever fuck leaving alone week new bong gt
# ofcourse --> ofcourse also upload song
# 2p --> 2p per min call germany 08448350055 bt line just 2p per min check planettalkinstantcom info t c text stop opt
# sent --> k will sent
# loti --> oh thanks loti already bought 2 egg
# sent --> k will sent
# sch --> u studying sch going home anyway ill b going 2 sch later
# game --> marvel mobile play official ultimate spiderman game £450 ur mobile right now text spider 83338 game ll send u free 8ball wallpaper
# tamilnaduthen --> think rule tamilnaduthen tough people
# go --> cool shall go see go tip anyway home got something drop later let go town tonight maybe mum can take u
# boytoy --> good afternoon love go day sleep hope well boytoy think
# trust --> yes trust u buy new stuff asap can try
# 08702840625comuk --> sm service inclusive text credit pls goto wwwcomuknet login 3qxj9 unsubscribe stop extra charge help 08702840625comuk 220cm2 9ae
# gt --> wake gt
# outta --> now get step 2 outta way congrats
# law --> love one law make happy person love way friendship one law never make ur friend feel alone alive gud night
# 07808247860 --> private 2003 account statement 07808247860 show 800 unredeemed s m point call 08719899229 identifier code 40411 expires 061104
# apo --> apo mokka player
# identification --> perhaps much easy give account identification will tomorrow uni
# wait --> wait will msg ltgt min
# tell --> told tell stupid hear wont tell anything dad called brother spoken
# god --> god love limit god grace measure god power boundary may u god endless blessing always ur life gud ni8
# inside --> want inside every night
# machan --> machan go gym tomorrow wil come late goodnight
# mad --> lol mad first woke gave
# centre --> went project centre
# reassuring --> it‘s reassuring crazy world
# making --> just making dinner
# leave --> yes please leave ltgt ltgt can leave
# lorwe --> oh okie lorwe go sat
# wish --> great role model giving much really wish day miracle god reason everything must say wish knew dont ive looked since young still great day
# liaoso --> ya im referin mei ex wat ah waitin 4 u treat somebody shld b rich liaoso gd den u dun work frm tmr onwards
# mile --> mile smile r made frm letter u know d difference smile ur face keep happy even though mile away u keep smiling good nyt
# house --> way ive put skip right outside front house can see house just pull
# colany --> can pls send company name saibaba colany
# hear --> dont want hear anything
# chic --> big chic common declare
# cool --> thats cool want please
# join --> going join tomorrow
# warranty --> awarded sipix digital camera call 09061221061 landline delivery within 28days t c box177 m221bp 2yr warranty 150ppm 16 p p£399
# lately --> want tell bad feel basically time text lately need drug
# 49557 --> private 2003 account statement show 800 unredeemed sim point call 08718738001 identifier code 49557 expires 261104
# disappointment --> total disappointment texted craziest shit got
# irritation --> just effect irritation just ignore
# one --> one
# tantrum --> think tantrum finished yeah ill point
# compliment --> compliment away system side
# adventuring --> happened adventuring
# chief --> hey chief can give bell get need talk royal visit 1st june
# another --> ok another number
# malaria --> know thinkin malaria relax child cant handle malaria worse gastroenteritis take enough replace loss temp will reduce give malaria med now will just vomit self limiting illness mean day will completely stop
# wat --> aiyah ok wat long got improve can already wat
# wc1n --> want explicit sex 30 sec ring 02073162414 now cost 20pmin gsex pobox 2667 wc1n 3xx
# attached --> cant believe attached seeing every day know will best can get babe will go teach class midnight
# sleepingand --> just sleepingand surfing
# inclu --> asked 3mobile 0870 chatlines inclu free min india cust servs sed yes l8er got mega bill 3 dont giv shit bailiff due day o £250 3 want £800
# rite --> yeah jus rite
# epsilon --> armand say get as epsilon
# jacket --> u still havent got urself jacket ah
# desk --> im taking derek amp taylor walmart im back time youre done just leave mouse desk ill text priscillas ready
# durban --> hi durban still number
# childporn --> ic lotta childporn car
# text --> contract mobile 11 mnths latest motorola nokia etc free double min text orange tariff text yes callback remove record
# weekend --> trying weekend v
# belt --> know wot people wear t shirt jumper hat belt know r cribbs
# cool --> cool time think can get
# spiritual --> wen get spiritual deep thats great
# share --> safe trip nigeria wish happiness soon company share moment
# hahahause --> hahahause brain dear
# influx --> well keep mind ive got enough gas one round trip barring sudden influx cash
# soon --> yeh indian nice tho kane bit shud go 4 drink sometime soon mite hav 2 go 2 da work 4 laugh soon love pete x x
# pshewmissing --> yes thats u texted pshewmissing much
# school --> meant calculation ltgt unit ltgt school really expensive started practicing accent important decided 4years dental school youll just nmde exam
# later --> sorry ill call later
# flip --> arent next ltgt hour imma flip shit
# lor --> anything lor juz u lor
# lowes --> get dump heap mom decided come lowes boring
# salesman --> ok lor sony ericsson salesman ask shuhui say quite gd 2 use considering
# ard --> ard 6 like dat lor
# wednesday --> dont wait til least wednesday see get
# huh --> huh y lei
# postcode --> reminder o2 get 250 pound free call credit detail great offer pls reply 2 text valid name house postcode
# 087187272008 --> 2nd time tried 2 contact u u won £750 pound prize 2 claim easy call 087187272008 now1 10p per minute btnationalrate
# esplanade --> will ü b going esplanade fr home
# soany --> pity mood soany suggestion
# bitching --> guy bitching acted like id interested buying something else next week gave u free
# rofl --> rofl true name

# %% [markdown]
# Having our text normalized and vectorized, let's finally proceed to machine learning!

# %% [markdown]
# ### 3. Classification

# %% [markdown]
# To classify messages as spam/ham (binary classification), we will compare three different sets of features:
# 1. Length of messages only
# 2. Term frequencies (counts)
# 3. Tf-idf
#
# We will also compare these classifiers to a naive baseline which predicts the most frequent class. Before starting, make sure that you have all the features and the target labels ready for the modelling.

# %%
import numpy as np

# %%
X_len = data_df['message_len'].values
X_len = X_len.reshape(-1, 1) # Since we it is single feature
X_bow_counts = bow_counts
X_bow_tfidf = bow_tfidf
y = data_df['type'].apply(lambda x: 1 if x == 'spam' else 0).values
labels = np.array(['ham', 'spam'])

# %%
print(X_len.shape)
print(X_bow_counts.shape)
print(X_bow_tfidf.shape)
print(y.shape)
# Out:
# (5572, 1)
# (5572, 8909)
# (5572, 8909)
# (5572,)

# %% [markdown]
# We will use 80%/20% train/test split. Note that as the data is imbalanced, this split should be stratified, i.e., the proportion of spam messages in the test set should be the same as in the whole dataset.

# %%
# train/test split
from sklearn.model_selection import train_test_split

rs = 42 # reproducible results, set to None for random
(X_len_train, X_len_test, X_bow_counts_train, X_bow_counts_test, 
 X_bow_tfidf_train, X_bow_tfidf_test, y_train, y_test) = train_test_split(
    X_len, X_bow_counts, X_bow_tfidf, y,
    test_size=0.2, stratify=y, random_state=rs)

# %% [markdown]
# Check if the proportion of the spam messages is the same in the test set and the whole dataset.

# %%
print("Spam/ham ratio in the whole dataset:", np.sum(y) / len(y))
print("Spam/ham ratio in the test set:", np.sum(y_test) / len(y_test))
# Out:
# Spam/ham ratio in the whole dataset: 0.13406317300789664
# Spam/ham ratio in the test set: 0.1336322869955157

# %% [markdown]
# **Naive baseline**

# %% [markdown]
# Always start with the simplest baseline, for example, predicting the most frequent class in the training set. Use standard performance metrics such as confusion matrix and F1 score.

# %%
# https://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

from sklearn.metrics import confusion_matrix
from sklearn.utils.multiclass import unique_labels

def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

# %%
from sklearn.dummy import DummyClassifier
from sklearn.metrics import classification_report

dummy_classifier = DummyClassifier(strategy="most_frequent", random_state=rs)
dummy_classifier.fit(X_len_train, y_train)
# Out:
# DummyClassifier(random_state=42, strategy='most_frequent')

# %%
y_pred = dummy_classifier.predict(X_len_test)
print(classification_report(y_test, y_pred, target_names=labels))
plot_confusion_matrix(y_test, y_pred, labels)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.87      1.00      0.93       966
#         spam       0.00      0.00      0.00       149
#
#     accuracy                           0.87      1115
#    macro avg       0.43      0.50      0.46      1115
# weighted avg       0.75      0.87      0.80      1115
#
# Confusion matrix, without normalization
# [[966   0]
#  [149   0]]
# /mnt/sdb1/camara/workspace/Causality_class/env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /mnt/sdb1/camara/workspace/Causality_class/env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /mnt/sdb1/camara/workspace/Causality_class/env/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **Classification using the message length only**

# %% [markdown]
# Train classifier which uses the message length as the only feature. Use your favorite model (e.g. Logistic Regression, Support Vector Machine or Neural Net). Remember which implications the data imbalance might have for the model training (e.g., set `class_weight='balanced'` for `sklearn.linear_model.LogisticRegression`). Use standard performance metrics such as confusion matrix and F1 score.
#
# *Optional: If you want, you can balance the training set directly, for instance, using upsampling or downsampling.*
#
# *Optional: You can also tune hyperparameters (e.g. `C` in `sklearn.linear_model.LogisticRegression`), for example, using grid search on the training set based on cross-validation.*

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

parameters = {'C': [10e-10, 0.1, 1, 10, 10e10]}
lr = GridSearchCV(LogisticRegression(class_weight='balanced', solver='lbfgs'), 
                  parameters, cv=5)
lr.fit(X_len_train, y_train)
print(lr.best_params_)
# Out:
# {'C': 0.1}

# %%
y_pred = lr.predict(X_len_test)
print(classification_report(y_test, y_pred, target_names=labels))
plot_confusion_matrix(y_test, y_pred, labels)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.97      0.78      0.87       966
#         spam       0.37      0.85      0.52       149
#
#     accuracy                           0.79      1115
#    macro avg       0.67      0.82      0.69      1115
# weighted avg       0.89      0.79      0.82      1115
#
# Confusion matrix, without normalization
# [[753 213]
#  [ 22 127]]

# %% [markdown]
# **Classification using term frequencies (counts)**

# %% [markdown]
# Train classifier which uses the term frequencies as features. Use standard performance metrics such as confusion matrix and F1 score.

# %%
parameters = {'C': [10e-10, 0.1, 1, 10, 10e10]}
lr = GridSearchCV(LogisticRegression(class_weight='balanced', solver='lbfgs'), 
                  parameters, cv=5)
lr.fit(X_bow_counts_train, y_train)
print(lr.best_params_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9fa910843074> in <module>
#       1 parameters = {'C': [10e-10, 0.1, 1, 10, 10e10]}
# ----> 2 lr = GridSearchCV(LogisticRegression(class_weight='balanced', solver='lbfgs'),
#       3                   parameters, cv=5)
#       4 lr.fit(X_bow_counts_train, y_train)
#       5 print(lr.best_params_)
#
# NameError: name 'GridSearchCV' is not defined

# %%
y_pred = lr.predict(X_bow_counts_test)
print(classification_report(y_test, y_pred, target_names=labels))
plot_confusion_matrix(y_test, y_pred, labels)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       966
#         spam       0.99      0.90      0.94       149
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.95      0.97      1115
# weighted avg       0.98      0.98      0.98      1115
#
# Confusion matrix, without normalization
# [[964   2]
#  [ 15 134]]

# %% [markdown]
# **Classification using tf-idf matrix**

# %% [markdown]
# Train classifier which uses the tf-idf matrix as features. Use standard performance metrics such as confusion matrix and F1 score.

# %%
parameters = {'C': [10e-10, 0.1, 1, 10, 10e10]}
lr = GridSearchCV(LogisticRegression(class_weight='balanced', solver='lbfgs'), 
                  parameters, cv=5)
lr.fit(X_bow_tfidf_train, y_train)
print(lr.best_params_)
# Out:
# {'C': 100000000000.0}

# %%
y_pred = lr.predict(X_bow_tfidf_test)
print(classification_report(y_test, y_pred, target_names=labels))
plot_confusion_matrix(y_test, y_pred, labels)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      1.00      0.99       966
#         spam       0.97      0.88      0.92       149
#
#     accuracy                           0.98      1115
#    macro avg       0.98      0.94      0.96      1115
# weighted avg       0.98      0.98      0.98      1115
#
# Confusion matrix, without normalization
# [[962   4]
#  [ 18 131]]

# %% [markdown]
# Which model performs better? Discuss your results with another student.

# %% [markdown]
# One common treatment (but not at all the only one!) an unbalanced dataset is to upsample the lower sample classe(s). Below is a code that you can try.

# %% [raw]
# # balancing example: upsampling the minor class (spam)
# from sklearn.utils import resample
#
# def balance_data(df):
#     # Separate majority and minority classes
#     df_spam = df[df.type=='spam']
#     df_ham = df[df.type=='ham']
#
#     # Upsample minority class
#     df_spam_upsampled = resample(df_spam, replace=True, n_samples=len(df_ham),
#                                  random_state=rs)
#
#     # Combine majority class with upsampled minority class
#     df_balanced = pd.concat([df_ham, df_spam_upsampled])
#
#     # Display new class counts
#     print(df_balanced.type.value_counts())
#
#     return df_balanced

# %% [markdown]
# ### 4. Topic modeling

# %% [markdown]
# Topic modeling is a useful set of techniques to represent a document as a set of concepts (or "topics"). Conceptually, it is similar to eigenvector decomposition (Principal Component Analysis, PCA), when each data point (document) is represented as a weighted sum of different eigenvectors (topics). Topics and decompositions are learned by the algorithm in an unsupervised manner. We will use the most popular one -- Latent Dirichlet Allocation (LDA). There are many implementations of the LDA algorithm in different languages and libraries, including `sklearn`.

# %%
from sklearn.decomposition import LatentDirichletAllocation

n_topics = 7
lda = LatentDirichletAllocation(n_components=n_topics, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)

# %% [markdown]
# Let's run the LDA algorithm. Note that it is designed to take term frequency matrix (counts) as an input, however, it is possible to run on tf-idf matrix as well.

# %%
X_lda_train = lda.fit_transform(X_bow_counts_train)

# %% [markdown]
# Print top N words together with their weights in each topic

# %%
def print_top_words(model, feature_names, n_top_words):
    norm = model.components_.sum(axis=1)[:, np.newaxis]
    for topic_idx, topic in enumerate(model.components_):
        print(80 * "-")
        print("Topic {}".format(topic_idx))
        for i in topic.argsort()[:-n_top_words - 1:-1]:
            print("{:.3f}".format(topic[i] / norm[topic_idx][0]) 
                  + '\t' + feature_names[i])

# %%
print("\nTopics in LDA model:")
counts_feature_names = count_vect.get_feature_names()
n_top_words = 10
print_top_words(lda, counts_feature_names, n_top_words)
# Out:
# Topics in LDA model:
# --------------------------------------------------------------------------------
# Topic 0
# 0.026	free
# 0.024	call
# 0.015	now
# 0.015	txt
# 0.014	text
# 0.014	ur
# 0.011	reply
# 0.011	stop
# 0.011	mobile
# 0.009	phone
# --------------------------------------------------------------------------------
# Topic 1
# 0.012	show
# 0.010	point
# 0.008	account
# 0.007	test
# 0.007	live
# 0.006	call
# 0.006	private
# 0.006	statement
# 0.005	expires
# 0.005	code
# --------------------------------------------------------------------------------
# Topic 2
# 0.031	hi
# 0.010	ok
# 0.009	hows
# 0.009	said
# 0.008	thanx
# 0.008	dont
# 0.006	missing
# 0.006	came
# 0.006	hand
# 0.006	sexy
# --------------------------------------------------------------------------------
# Topic 3
# 0.014	cool
# 0.007	ltgt
# 0.005	noe
# 0.004	address
# 0.004	went
# 0.004	im
# 0.004	post
# 0.004	hee
# 0.004	ha
# 0.004	chennai
# --------------------------------------------------------------------------------
# Topic 4
# 0.027	call
# 0.019	claim
# 0.016	prize
# 0.013	urgent
# 0.013	cash
# 0.012	won
# 0.009	holiday
# 0.008	contact
# 0.007	guaranteed
# 0.007	number
# --------------------------------------------------------------------------------
# Topic 5
# 0.014	im
# 0.011	can
# 0.010	will
# 0.009	get
# 0.009	just
# 0.009	now
# 0.009	go
# 0.008	got
# 0.008	ill
# 0.008	ltgt
# --------------------------------------------------------------------------------
# Topic 6
# 0.009	face
# 0.007	simple
# 0.006	ltgt
# 0.004	opinion
# 0.003	character
# 0.003	malaria
# 0.003	silent
# 0.003	waste
# 0.003	hai
# 0.002	grl

# %% [markdown]
# Do they have any meaning? Discuss with another student. Try to experiment with different numbers of topics and see how it affects their interpretability.

# %% [markdown]
# **Classification using LDA**

# %% [markdown]
# Train classifier which uses topic weights for each document (message) as features for the case `n_topics = 7`. Use standard performance metrics such as confusion matrix and F1 score.

# %%
X_lda_test = lda.transform(X_bow_counts_test)

# %%
parameters = {'C': [10e-10, 0.1, 1, 10, 10e10]}
lr = GridSearchCV(LogisticRegression(class_weight='balanced', solver='lbfgs'), 
                  parameters, cv=5)
lr.fit(X_lda_train, y_train)
print(lr.best_params_)
# Out:
# {'C': 1e-09}

# %%
y_pred = lr.predict(X_lda_test)
print(classification_report(y_test, y_pred, target_names=labels))
plot_confusion_matrix(y_test, y_pred, labels)
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.98      0.96      0.97       966
#         spam       0.76      0.85      0.80       149
#
#     accuracy                           0.94      1115
#    macro avg       0.87      0.91      0.89      1115
# weighted avg       0.95      0.94      0.95      1115
#
# Confusion matrix, without normalization
# [[926  40]
#  [ 22 127]]

# %% [markdown]
# Not bad! You can get very good performance using only a small number of features for each message instead of thousands of words!

# %% [markdown]
# Finally, plot the classification performance for different numbers of topics. Also, inspect topics for the best performing model.
#
# *Note: The topics number is itself a hyperparameter, which should be tuned using the training set only (e.g. using a 3-way CV). However, as LDA can be computationally demanding, we will skip this part and calculate the performance for the different number of topics directly on the test set.*

# %%
n_topics_list = list(range(3, 16, 2))
performance = []
#
for n_topics in n_topics_list:
    lda = LatentDirichletAllocation(n_components=n_topics, max_iter=5,
                                learning_method='online',
                                learning_offset=50.,
                                random_state=0)
    X_lda_train = lda.fit_transform(X_bow_counts_train)
    X_lda_test = lda.transform(X_bow_counts_test)
    parameters = {'C': [10e-10, 0.1, 1, 10, 10e10]}
    lr = GridSearchCV(LogisticRegression(class_weight='balanced', solver='lbfgs'), 
                      parameters, cv=3)
    lr.fit(X_lda_train, y_train)
    print(lr.best_params_)
    y_pred = lr.predict(X_lda_test)
    report = classification_report(y_test, y_pred, 
                                   target_names=labels, output_dict=True)
    performance.append(report['macro avg']['f1-score'])
# Out:
# {'C': 0.1}
# {'C': 0.1}
# {'C': 1e-09}
# {'C': 1e-09}
# {'C': 0.1}
# {'C': 100000000000.0}
# {'C': 0.1}

# %%
plt.plot(n_topics_list, performance)
plt.show();
